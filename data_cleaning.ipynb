# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"/Users/darshan/Documents/ML/Data/loan_application_data.csv")
dataset.head(3)
# Out:
#   Application_ID    Status Loan_Type Employment_Status  Annual_Income  \
# 0      AID-00001  Rejected       NaN               NaN        28518.0
# 1      AID-00002   Pending      Home               NaN            NaN
# 2      AID-00003   Pending      Home     Self-Employed        22306.0
#
#    Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married Dependents  \
# 0          NaN                   NaN         834.0     NaN     Yes          1
# 1      49365.0                  36.0         647.0  Female      No          1
# 2       5608.0                   NaN         357.0     NaN      No          2
#
#   Education
# 0  Graduate
# 1  Graduate
# 2  Graduate

# %%
dataset.shape
# Out:
# (1000, 12)

# %%
dataset.shape
# Out:
# (1000, 12)

# %%
((1000-89)/1000)*100
# Out:
# 91.10000000000001

# %%
dataset.isnull().sum()
# Out:
# Application_ID            0
# Status                  251
# Loan_Type               200
# Employment_Status       283
# Annual_Income           103
# Loan_Amount             126
# Loan_Duration_Months    174
# Credit_Score            181
# Gender                  338
# Married                 326
# Dependents              165
# Education               347
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Application_ID            0
# Status                  251
# Loan_Type               200
# Employment_Status       283
# Annual_Income           103
# Loan_Amount             126
# Loan_Duration_Months    174
# Credit_Score            181
# Gender                  338
# Married                 326
# Dependents              165
# Education               347
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 2494

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Application_ID           0.0
# Status                  25.1
# Loan_Type               20.0
# Employment_Status       28.3
# Annual_Income           10.3
# Loan_Amount             12.6
# Loan_Duration_Months    17.4
# Credit_Score            18.1
# Gender                  33.8
# Married                 32.6
# Dependents              16.5
# Education               34.7
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# 20.783333333333335

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#dataset.drop(columns=["Education"],inplace=True)

# %%
#dataset.dropna(inplace=True)

# %%
dataset.head(10)
# Out:
#   Application_ID    Status  Loan_Type Employment_Status  Annual_Income  \
# 0      AID-00001  Rejected        NaN               NaN        28518.0
# 1      AID-00002   Pending       Home               NaN            NaN
# 2      AID-00003   Pending       Home     Self-Employed        22306.0
# 3      AID-00004  Rejected        NaN               NaN        93657.0
# 4      AID-00005   Pending       Home          Employed        93819.0
# 5      AID-00006  Rejected  Education        Unemployed       150614.0
# 6      AID-00007  Rejected   Personal     Self-Employed        55935.0
# 7      AID-00008  Approved       Auto     Self-Employed       145235.0
# 8      AID-00009       NaN       Home               NaN       110780.0
# 9      AID-00010  Approved        NaN     Self-Employed        47879.0
#
#    Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married Dependents  \
# 0          NaN                   NaN         834.0     NaN     Yes          1
# 1      49365.0                  36.0         647.0  Female      No          1
# 2       5608.0                   NaN         357.0     NaN      No          2
# 3      38793.0                   NaN         636.0    Male      No          2
# 4       5920.0                  48.0         601.0     NaN     Yes          1
# 5      26850.0                  60.0           NaN     NaN     Yes          3
# 6      30592.0                  24.0         370.0  Female     Yes          2
# 7      45951.0                  60.0         447.0     NaN      No          1
# 8          NaN                  12.0         821.0    Male     Yes         3+
# 9      33716.0                  48.0         411.0  Female     NaN          1
#
#       Education
# 0      Graduate
# 1      Graduate
# 2      Graduate
# 3           NaN
# 4           NaN
# 5           NaN
# 6      Graduate
# 7      Graduate
# 8      Graduate
# 9  Not Graduate

# %%
#dataset.bfill(inplace=True)

# %%
#dataset.ffill(inplace=True)

# %%
dataset.head(20)
# Out:
#    Application_ID    Status  Loan_Type Employment_Status  Annual_Income  \
# 0       AID-00001  Rejected        NaN               NaN        28518.0
# 1       AID-00002   Pending       Home               NaN            NaN
# 2       AID-00003   Pending       Home     Self-Employed        22306.0
# 3       AID-00004  Rejected        NaN               NaN        93657.0
# 4       AID-00005   Pending       Home          Employed        93819.0
# 5       AID-00006  Rejected  Education        Unemployed       150614.0
# 6       AID-00007  Rejected   Personal     Self-Employed        55935.0
# 7       AID-00008  Approved       Auto     Self-Employed       145235.0
# 8       AID-00009       NaN       Home               NaN       110780.0
# 9       AID-00010  Approved        NaN     Self-Employed        47879.0
# 10      AID-00011   Pending       Auto     Self-Employed       172817.0
# 11      AID-00012       NaN       Auto               NaN        92105.0
# 12      AID-00013   Pending  Education               NaN       119918.0
# 13      AID-00014       NaN        NaN        Unemployed       174015.0
# 14      AID-00015   Pending  Education     Self-Employed       161213.0
# 15      AID-00016  Approved  Education          Employed       103480.0
# 16      AID-00017   Pending   Personal          Employed       155524.0
# 17      AID-00018   Pending       Auto     Self-Employed            NaN
# 18      AID-00019  Rejected       Auto          Employed        66228.0
# 19      AID-00020       NaN       Home          Employed       161529.0
#
#     Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married  \
# 0           NaN                   NaN         834.0     NaN     Yes
# 1       49365.0                  36.0         647.0  Female      No
# 2        5608.0                   NaN         357.0     NaN      No
# 3       38793.0                   NaN         636.0    Male      No
# 4        5920.0                  48.0         601.0     NaN     Yes
# 5       26850.0                  60.0           NaN     NaN     Yes
# 6       30592.0                  24.0         370.0  Female     Yes
# 7       45951.0                  60.0         447.0     NaN      No
# 8           NaN                  12.0         821.0    Male     Yes
# 9       33716.0                  48.0         411.0  Female     NaN
# 10      19380.0                  60.0         828.0    Male      No
# 11      17012.0                  12.0         341.0     NaN     Yes
# 12      40609.0                  48.0         592.0  Female     NaN
# 13      35412.0                  36.0           NaN  Female     Yes
# 14      27945.0                  48.0         788.0     NaN      No
# 15      21717.0                  24.0         481.0    Male     Yes
# 16      30247.0                  36.0         779.0    Male     NaN
# 17      20724.0                   NaN         324.0    Male      No
# 18      35690.0                  60.0         553.0  Female      No
# 19      21242.0                  36.0         676.0     NaN     NaN
#
#    Dependents     Education
# 0           1      Graduate
# 1           1      Graduate
# 2           2      Graduate
# 3           2           NaN
# 4           1           NaN
# 5           3           NaN
# 6           2      Graduate
# 7           1      Graduate
# 8          3+      Graduate
# 9           1  Not Graduate
# 10          0           NaN
# 11          0           NaN
# 12          2  Not Graduate
# 13          2  Not Graduate
# 14          1  Not Graduate
# 15          0      Graduate
# 16        NaN  Not Graduate
# 17         3+  Not Graduate
# 18          3           NaN
# 19        NaN      Graduate

# %%
dataset.isnull().sum()
# Out:
# Application_ID            0
# Status                  251
# Loan_Type               200
# Employment_Status       283
# Annual_Income           103
# Loan_Amount             126
# Loan_Duration_Months    174
# Credit_Score            181
# Gender                  338
# Married                 326
# Dependents              165
# Education               347
# dtype: int64

# %%
dataset["Gender"].mode()
# Out:
# 0    Female
# Name: Gender, dtype: object

# %%
dataset["Gender"].mode()[0]
# Out:
# 'Female'

# %%
dataset["Gender"].fillna(dataset["Gender"].mode()[0],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Application_ID            0
# Status                    0
# Loan_Type               200
# Employment_Status       283
# Annual_Income           103
# Loan_Amount             126
# Loan_Duration_Months    174
# Credit_Score            181
# Gender                    0
# Married                 326
# Dependents              165
# Education               347
# dtype: int64

# %%
dataset.head(20)
# Out:
#    Application_ID    Status  Loan_Type Employment_Status  Annual_Income  \
# 0       AID-00001  Rejected        NaN               NaN        28518.0
# 1       AID-00002   Pending       Home               NaN            NaN
# 2       AID-00003   Pending       Home     Self-Employed        22306.0
# 3       AID-00004  Rejected        NaN               NaN        93657.0
# 4       AID-00005   Pending       Home          Employed        93819.0
# 5       AID-00006  Rejected  Education        Unemployed       150614.0
# 6       AID-00007  Rejected   Personal     Self-Employed        55935.0
# 7       AID-00008  Approved       Auto     Self-Employed       145235.0
# 8       AID-00009   Pending       Home               NaN       110780.0
# 9       AID-00010  Approved        NaN     Self-Employed        47879.0
# 10      AID-00011   Pending       Auto     Self-Employed       172817.0
# 11      AID-00012   Pending       Auto               NaN        92105.0
# 12      AID-00013   Pending  Education               NaN       119918.0
# 13      AID-00014   Pending        NaN        Unemployed       174015.0
# 14      AID-00015   Pending  Education     Self-Employed       161213.0
# 15      AID-00016  Approved  Education          Employed       103480.0
# 16      AID-00017   Pending   Personal          Employed       155524.0
# 17      AID-00018   Pending       Auto     Self-Employed            NaN
# 18      AID-00019  Rejected       Auto          Employed        66228.0
# 19      AID-00020   Pending       Home          Employed       161529.0
#
#     Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married  \
# 0           NaN                   NaN         834.0  Female     Yes
# 1       49365.0                  36.0         647.0  Female      No
# 2        5608.0                   NaN         357.0  Female      No
# 3       38793.0                   NaN         636.0    Male      No
# 4        5920.0                  48.0         601.0  Female     Yes
# 5       26850.0                  60.0           NaN  Female     Yes
# 6       30592.0                  24.0         370.0  Female     Yes
# 7       45951.0                  60.0         447.0  Female      No
# 8           NaN                  12.0         821.0    Male     Yes
# 9       33716.0                  48.0         411.0  Female     NaN
# 10      19380.0                  60.0         828.0    Male      No
# 11      17012.0                  12.0         341.0  Female     Yes
# 12      40609.0                  48.0         592.0  Female     NaN
# 13      35412.0                  36.0           NaN  Female     Yes
# 14      27945.0                  48.0         788.0  Female      No
# 15      21717.0                  24.0         481.0    Male     Yes
# 16      30247.0                  36.0         779.0    Male     NaN
# 17      20724.0                   NaN         324.0    Male      No
# 18      35690.0                  60.0         553.0  Female      No
# 19      21242.0                  36.0         676.0  Female     NaN
#
#    Dependents     Education
# 0           1      Graduate
# 1           1      Graduate
# 2           2      Graduate
# 3           2           NaN
# 4           1           NaN
# 5           3           NaN
# 6           2      Graduate
# 7           1      Graduate
# 8          3+      Graduate
# 9           1  Not Graduate
# 10          0           NaN
# 11          0           NaN
# 12          2  Not Graduate
# 13          2  Not Graduate
# 14          1  Not Graduate
# 15          0      Graduate
# 16        NaN  Not Graduate
# 17         3+  Not Graduate
# 18          3           NaN
# 19        NaN      Graduate

# %%
dataset["Status"].fillna(dataset["Status"].mode()[0],inplace=True)

# %%
dataset.select_dtypes(include="object")
# Out:
#     Application_ID    Status  Loan_Type Employment_Status  Gender Married  \
# 0        AID-00001  Rejected        NaN               NaN  Female     Yes
# 1        AID-00002   Pending       Home               NaN  Female      No
# 2        AID-00003   Pending       Home     Self-Employed  Female      No
# 3        AID-00004  Rejected        NaN               NaN    Male      No
# 4        AID-00005   Pending       Home          Employed  Female     Yes
# ..             ...       ...        ...               ...     ...     ...
# 995      AID-00996   Pending        NaN     Self-Employed    Male      No
# 996      AID-00997  Rejected       Auto          Employed  Female     NaN
# 997      AID-00998   Pending       Home          Employed  Female     Yes
# 998      AID-00999   Pending   Personal     Self-Employed    Male      No
# 999      AID-01000  Approved  Education               NaN  Female     NaN
#
#     Dependents     Education
# 0            1      Graduate
# 1            1      Graduate
# 2            2      Graduate
# 3            2           NaN
# 4            1           NaN
# ..         ...           ...
# 995          0  Not Graduate
# 996          3  Not Graduate
# 997        NaN  Not Graduate
# 998          0      Graduate
# 999          0           NaN
#
# [1000 rows x 8 columns]

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# Application_ID         0
# Status                 0
# Loan_Type            200
# Employment_Status    283
# Gender                 0
# Married              326
# Dependents           165
# Education            347
# dtype: int64

# %%
dataset.select_dtypes(include="object").columns
# Out:
# Index(['Application_ID', 'Status', 'Loan_Type', 'Employment_Status', 'Gender',
#        'Married', 'Dependents', 'Education'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include="object").columns:
    dataset[i].fillna(dataset[i].mode()[0],inplace=True)

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# Application_ID       0
# Status               0
# Loan_Type            0
# Employment_Status    0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Application_ID          0
# Status                  0
# Loan_Type               0
# Employment_Status       0
# Annual_Income           0
# Loan_Amount             0
# Loan_Duration_Months    0
# Credit_Score            0
# Gender                  0
# Married                 0
# Dependents              0
# Education               0
# dtype: int64

# %%
dataset["Annual_Income"].fillna(dataset["Annual_Income"].mode()[0],inplace=True)

# %%
dataset.head(20)
# Out:
#    Application_ID    Status  Loan_Type Employment_Status  Annual_Income  \
# 0       AID-00001  Rejected   Personal     Self-Employed        28518.0
# 1       AID-00002   Pending       Home     Self-Employed        39748.0
# 2       AID-00003   Pending       Home     Self-Employed        22306.0
# 3       AID-00004  Rejected   Personal     Self-Employed        93657.0
# 4       AID-00005   Pending       Home          Employed        93819.0
# 5       AID-00006  Rejected  Education        Unemployed       150614.0
# 6       AID-00007  Rejected   Personal     Self-Employed        55935.0
# 7       AID-00008  Approved       Auto     Self-Employed       145235.0
# 8       AID-00009   Pending       Home     Self-Employed       110780.0
# 9       AID-00010  Approved   Personal     Self-Employed        47879.0
# 10      AID-00011   Pending       Auto     Self-Employed       172817.0
# 11      AID-00012   Pending       Auto     Self-Employed        92105.0
# 12      AID-00013   Pending  Education     Self-Employed       119918.0
# 13      AID-00014   Pending   Personal        Unemployed       174015.0
# 14      AID-00015   Pending  Education     Self-Employed       161213.0
# 15      AID-00016  Approved  Education          Employed       103480.0
# 16      AID-00017   Pending   Personal          Employed       155524.0
# 17      AID-00018   Pending       Auto     Self-Employed        39748.0
# 18      AID-00019  Rejected       Auto          Employed        66228.0
# 19      AID-00020   Pending       Home          Employed       161529.0
#
#     Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married  \
# 0       15207.0                  60.0         834.0  Female     Yes
# 1       49365.0                  36.0         647.0  Female      No
# 2        5608.0                  60.0         357.0  Female      No
# 3       38793.0                  60.0         636.0    Male      No
# 4        5920.0                  48.0         601.0  Female     Yes
# 5       26850.0                  60.0         508.0  Female     Yes
# 6       30592.0                  24.0         370.0  Female     Yes
# 7       45951.0                  60.0         447.0  Female      No
# 8       15207.0                  12.0         821.0    Male     Yes
# 9       33716.0                  48.0         411.0  Female      No
# 10      19380.0                  60.0         828.0    Male      No
# 11      17012.0                  12.0         341.0  Female     Yes
# 12      40609.0                  48.0         592.0  Female      No
# 13      35412.0                  36.0         508.0  Female     Yes
# 14      27945.0                  48.0         788.0  Female      No
# 15      21717.0                  24.0         481.0    Male     Yes
# 16      30247.0                  36.0         779.0    Male      No
# 17      20724.0                  60.0         324.0    Male      No
# 18      35690.0                  60.0         553.0  Female      No
# 19      21242.0                  36.0         676.0  Female      No
#
#    Dependents     Education
# 0           1      Graduate
# 1           1      Graduate
# 2           2      Graduate
# 3           2      Graduate
# 4           1      Graduate
# 5           3      Graduate
# 6           2      Graduate
# 7           1      Graduate
# 8          3+      Graduate
# 9           1  Not Graduate
# 10          0      Graduate
# 11          0      Graduate
# 12          2  Not Graduate
# 13          2  Not Graduate
# 14          1  Not Graduate
# 15          0      Graduate
# 16          2  Not Graduate
# 17         3+  Not Graduate
# 18          3      Graduate
# 19          2      Graduate

# %%
for i in dataset.select_dtypes(include="float").columns:
    dataset[i].fillna(dataset[i].mode()[0],inplace=True)
