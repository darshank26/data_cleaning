# %%
import pandas as pd

# %%
df = pd.DataFrame({"sizes":["S","M","L","XL","M","S","L","M","S","XL","S","L","XXL","XL","S","L"]})
df.head(3)
# Out:
#   sizes
# 0     S
# 1     M
# 2     L

# %%
ord_data = [["S","M","L","XL","XXL"]]
ord_data
# Out:
# [['S', 'M', 'L', 'XL', 'XXL']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# from Sklearn

ord = OrdinalEncoder(categories=ord_data)
ord.fit(df[["sizes"]])
df["en_sizes"]=ord.transform(df[["sizes"]])
df
# Out:
#    sizes  en_sizes
# 0      S       0.0
# 1      M       1.0
# 2      L       2.0
# 3     XL       3.0
# 4      M       1.0
# 5      S       0.0
# 6      L       2.0
# 7      M       1.0
# 8      S       0.0
# 9     XL       3.0
# 10     S       0.0
# 11     L       2.0
# 12   XXL       4.0
# 13    XL       3.0
# 14     S       0.0
# 15     L       2.0

# %%
# From map 

ord_data_map = {"S" : 2 ,"M": 4 ,"L" : 8 ,"XL" : 10 ,"XXL" : 12 }
ord_data_map
# Out:
# {'S': 2, 'M': 4, 'L': 8, 'XL': 10, 'XXL': 12}

# %%
df["en_sizes_map"] = df["sizes"].map(ord_data_map)
df
# Out:
#    sizes  en_sizes  en_sizes_map
# 0      S       0.0             2
# 1      M       1.0             4
# 2      L       2.0             8
# 3     XL       3.0            10
# 4      M       1.0             4
# 5      S       0.0             2
# 6      L       2.0             8
# 7      M       1.0             4
# 8      S       0.0             2
# 9     XL       3.0            10
# 10     S       0.0             2
# 11     L       2.0             8
# 12   XXL       4.0            12
# 13    XL       3.0            10
# 14     S       0.0             2
# 15     L       2.0             8

# %%
dataset = pd.read_csv(r"/Users/darshan/Documents/ML/Data/loan.csv")
dataset.head(10)
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
# 5           5  LP001011   Male     Yes          2      Graduate           Yes
# 6           6  LP001013   Male     Yes          0  Not Graduate            No
# 7           7  LP001014   Male     Yes         3+      Graduate            No
# 8           8  LP001018   Male     Yes          2      Graduate            No
# 9           9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                9
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# Loan_Status           0
# Total_Income          0
# dtype: int64

# %%
dataset['Property_Area'].unique()
# Out:
# array([0., 1., 2.])

# %%
# if null 
# 
#dataset['Property_Area'].fillna(dataset['Property_Area'].mode()[0],inplace=True)
#dataset['Property_Area']

# %%
property_ord_data = [['Urban', 'Rural', 'Semiurban']]

# %%
from sklearn.preprocessing import OrdinalEncoder
ordE = OrdinalEncoder(categories=property_ord_data)
dataset["Property_Area"] = ordE.fit_transform(dataset[["Property_Area"]])
dataset.head(10)
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
# 5           5  LP001011   Male     Yes          2      Graduate           Yes
# 6           6  LP001013   Male     Yes          0  Not Graduate            No
# 7           7  LP001014   Male     Yes         3+      Graduate            No
# 8           8  LP001018   Male     Yes          2      Graduate            No
# 9           9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset['Property_Area'].unique()
# Out:
# array([0., 1., 2.])
