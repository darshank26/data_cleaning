# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as py
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"/Users/darshan/Documents/ML/Data/level_vs_salary_exponential.csv")
df.head(3)
# Out:
#    Level       Salary
# 0      1  5025.062604
# 1      2  5050.250835
# 2      3  5075.565323

# %%
sns.scatterplot(x="Level",y="Salary",data=df,c="green")
py.show()

# %%
df.isnull().sum()
# Out:
# Level     0
# Salary    0
# dtype: int64

# %%
df.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.858069
# Salary  0.858069  1.000000

# %%
sns.heatmap(data = df.corr(), annot = True)
# Out:
# <Axes: >

# %%
df.count()
# Out:
# Level     1000
# Salary    1000
# dtype: int64

# %%
x = df[['Level']]
y = df[['Salary']]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree = 2)

# %%
pf.fit(x)
# Out:
# PolynomialFeatures()

# %%
x = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 96.30827686233744

# %%
prd = lr.predict(x)
py.scatter(df['Level'],df['Salary'])
py.plot(df['Level'],prd,c='red')
py.xlabel('Level')
py.ylabel('Salary')
py.legend(["org","prd"])
py.show()

# %%
test = pf.transform([[56]])
test
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.000e+00, 5.600e+01, 3.136e+03]])

# %%
lr.predict(test)
# Out:
# array([[37811.77395422]])
