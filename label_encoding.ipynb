# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame({"names":["Cat","Dog","Cow","Sheep","Goat","Ox","Rabbit"]})
df
# Out:
#     names
# 0     Cat
# 1     Dog
# 2     Cow
# 3   Sheep
# 4    Goat
# 5      Ox
# 6  Rabbit

# %%
en_data = df["names"]
le = LabelEncoder()
df["en_names"] = le.fit_transform(en_data)
df
# Out:
#     names  en_names
# 0     Cat         0
# 1     Dog         2
# 2     Cow         1
# 3   Sheep         6
# 4    Goat         3
# 5      Ox         4
# 6  Rabbit         5

# %%
dataset = pd.read_csv(r"/Users/darshan/Documents/ML/Data/loan_application_data.csv")
dataset.head(3)
# Out:
#   Application_ID    Status Loan_Type Employment_Status  Annual_Income  \
# 0      AID-00001  Rejected       NaN               NaN        28518.0
# 1      AID-00002   Pending      Home               NaN            NaN
# 2      AID-00003   Pending      Home     Self-Employed        22306.0
#
#    Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married Dependents  \
# 0          NaN                   NaN         834.0     NaN     Yes          1
# 1      49365.0                  36.0         647.0  Female      No          1
# 2       5608.0                   NaN         357.0     NaN      No          2
#
#   Education
# 0  Graduate
# 1  Graduate
# 2  Graduate

# %%
dataset.isnull().sum()
# Out:
# Application_ID            0
# Status                  251
# Loan_Type               200
# Employment_Status       283
# Annual_Income           103
# Loan_Amount             126
# Loan_Duration_Months    174
# Credit_Score            181
# Gender                  338
# Married                 326
# Dependents              165
# Education               347
# dtype: int64

# %%
dataset["Loan_Type"].unique()
# Out:
# array([nan, 'Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
en_le = dataset["Loan_Type"]
le_dataset = LabelEncoder()
dataset["Loan_Type"] = le_dataset.fit_transform(en_le)
dataset
# Out:
#     Application_ID    Status  Loan_Type Employment_Status  Annual_Income  \
# 0        AID-00001  Rejected          4               NaN        28518.0
# 1        AID-00002   Pending          2               NaN            NaN
# 2        AID-00003   Pending          2     Self-Employed        22306.0
# 3        AID-00004  Rejected          4               NaN        93657.0
# 4        AID-00005   Pending          2          Employed        93819.0
# ..             ...       ...        ...               ...            ...
# 995      AID-00996       NaN          4     Self-Employed       115173.0
# 996      AID-00997  Rejected          0          Employed        73932.0
# 997      AID-00998   Pending          2          Employed        95003.0
# 998      AID-00999       NaN          3     Self-Employed       104967.0
# 999      AID-01000  Approved          1               NaN       182270.0
#
#      Loan_Amount  Loan_Duration_Months  Credit_Score  Gender Married  \
# ...
